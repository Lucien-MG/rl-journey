# %%
import gym
import torch

# %%
ENVIRONMENT_ID = "Pendulum-v1"
RECORD_PATH = "../videos/reinforce/" + ENVIRONMENT_ID

# %% [markdown]
# ## Torch RL Library

# %%
import torch
import torch.nn as nn
import torch.distributions as dist

class Stochastic(nn.Module):

    def __init__(self, num_actions, distribution: torch.distributions.distribution.Distribution) -> None:
        super().__init__()

        self.num_actions = num_actions
        self.distribution = distribution
    
    def forward(self, states):
        probs = torch.full((states.shape[0], self.num_actions), fill_value=1/self.num_actions)
        return probs

    def policy(self, state):
        values = self.forward(state)
        if hasattr(self.distribution, 'logits'):
            policy = self.distribution(logits=values)
        else:
            policy = self.distribution(values, 0.1)
        return policy
    
    def action(self, state: torch.Tensor):
        action = self.policy(state).sample()
        return action


class Reinforce(torch.nn.Module):

    def __init__(self, model: torch.nn.Module, distribution: torch.distributions.distribution.Distribution) -> None:
        super().__init__()

        self.model = model
        self.distribution = distribution

    def forward(self, state: torch.Tensor):
        values = self.model(state)
        return values
    
    def policy(self, state: torch.Tensor):
        values = self.forward(state)
        if hasattr(self.distribution, 'logits'):
            policy = self.distribution(logits=values)
        else:
            policy = self.distribution(torch.tanh(values[:1]) * 2, torch.sigmoid(values[1:]))
            print(policy)
        return policy

    def action(self, state: torch.Tensor):
        action = self.policy(state).sample()
        print(action)
        return action

    def loss(self, state_batch: torch.Tensor, action_batch: torch.Tensor, reward_batch: torch.Tensor, done_batch: torch.Tensor):
        distribution = self.policy(state_batch)
        entropy = distribution.entropy().mean()
        logp = distribution.log_prob(action_batch)
        loss = -(logp * reward_batch).mean()
        return loss, entropy


class ActionBuffer():
    def __init__(self, gamma) -> None:
        super().__init__()
        self.gamma = gamma

        self.state_buffer = []
        self.action_buffer = []
        self.reward_buffer = []
        self.done_buffer = []

    def __len__(self):
        return len(self.state_buffer)
    
    def push(self, state, action, reward, done):
        self.state_buffer.append(state)
        self.action_buffer.append(action)
        self.reward_buffer.append(reward)
        self.done_buffer.append(done)
    
    def flush(self):
        for i in reversed(range(self.__len__())):
            self.reward_buffer[i - 1] = self.reward_buffer[i - 1] + (self.gamma * (self.reward_buffer[i] * (not self.done_buffer[i - 1])))
        
        state_batch = torch.cat(self.state_buffer)
        action_batch = torch.FloatTensor(self.action_buffer)
        reward_batch = torch.FloatTensor(self.reward_buffer)
        done_batch = torch.BoolTensor(self.done_buffer)

        self.__init__(self.gamma)

        return state_batch, action_batch, reward_batch, done_batch

def get_prob_from_pred(pred_batch, action_batch):
    return pred_batch.gather(dim=1,index=action_batch.long().view(-1,1)).squeeze()

def ascent_log_loss(action_values_batch, action_batch, reward_batch):
    distribution = dist.Categorical(logits=action_values_batch)
    logp = distribution.log_prob(action_batch)
    loss = -(logp * reward_batch).mean()
    return loss

def entropy_loss(action_values_batch, beta=0.1):
    p = torch.softmax(action_values_batch, dim=1)
    log_p = torch.log_softmax(action_values_batch, dim=1)
    entropy = -1 * torch.mean(torch.sum(p * log_p, dim=1), dim=0)
    entropy_bonus = -1 * beta * entropy
    return entropy_bonus

# %% [markdown]
# ## Gym Helpers

# %%
from math import exp
from gym.wrappers import RecordVideo

# Play episode
def play_episode(env, agent, record_path=None):
    if record_path:
        env = RecordVideo(env, video_folder=record_path, new_step_api=True)

    cumulative_reward = 0

    observation = env.reset()
    done = False

    while not done:
        torch_state = torch.FloatTensor(observation)
        action = agent.action(torch_state)

        observation, reward, terminated, truncarted, info = env.step(action.numpy())
        done = terminated or truncarted

        cumulative_reward += reward
    
    env.close()
    
    return cumulative_reward

def evaluate_agent(env, agent, num_episodes=100):
    reward = 0
    for episode in range(num_episodes):
        reward += play_episode(env, agent)
    return reward / num_episodes

def train_epoch(env, agent, optimizer, gamma=0.99, num_episode=32):
    memory = ActionBuffer(gamma)

    cumulative_rewards = []
    episodes_length = []

    for episode in range(num_episode):
        observation = env.reset()
        done = False

        tt_reward = 0
        ep_length = 0

        while not done:
            torch_state = torch.as_tensor(observation)
            torch_action = agent.action(torch_state)

            next_observation, reward, terminated, truncarted, info = env.step(torch_action.numpy())
            if type(reward) != "int":
                reward = reward[0]
            done = terminated or truncarted

            memory.push(torch_state, torch_action, reward, done)

            observation = next_observation

            tt_reward += reward 
            ep_length += 1

        cumulative_rewards.append(tt_reward)
        episodes_length.append(ep_length)

    state_batch, action_batch, reward_batch, done_batch = memory.flush()

    loss, entropy = agent.loss(state_batch, action_batch, reward_batch, done_batch)
    loss = loss + 0.1 * entropy

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    return cumulative_rewards, loss, entropy, episodes_length

# %% [markdown]
# ## Pre processing state:

# %%
def pre_processing_state(state):
    torch_state = torch.as_tensor(state)
    return torch_state

# %% [markdown]
# ## Run

# %%
# Parameters:
ALPHA = 1e-2
GAMMA = 0.99

BATCH_SIZE = 128
NB_EPOCH = 100

# %%
# Create environment
env = gym.make(ENVIRONMENT_ID, new_step_api=True)

# Infos Env
observation_space_size = env.observation_space.shape[0]
num_actions = env.action_space.n if type(env.action_space.sample()) == "int" else env.action_space.sample().shape[0]
is_continuous = env.action_space.dtype == "float32"

print("Environment Infos:")
print("  Observation Shape:", observation_space_size)
print("  Number of actions:", num_actions)
print("  Problem is continuous:", is_continuous)
# Out:
# Environment Infos:
#   Observation Shape: 3
#   Number of actions: 1
#   Problem is continuous: True

# %%
from torch.utils.tensorboard import SummaryWriter

writer = SummaryWriter(comment=f'_PG_CP_Gamma={GAMMA},'
                                f'LR={ALPHA},'
                                f'BS={BATCH_SIZE}')

# %%
if is_continuous:
    distribution = torch.distributions.Normal
else:
    distribution = torch.distributions.Categorical

# %%
model = nn.Sequential(
            nn.Linear(in_features=observation_space_size, out_features=32, bias=True),
            nn.PReLU(),
            nn.Linear(in_features=32, out_features=16, bias=True),
            nn.PReLU(),
            nn.Linear(in_features=16, out_features=num_actions + is_continuous, bias=True),
            nn.Identity()
        )

random_agent = Stochastic(num_actions=num_actions, distribution=distribution)
agent = Reinforce(model=model, distribution=distribution)

optimizer = torch.optim.Adam(params=agent.parameters(), lr=ALPHA)

# %%
reward_random = evaluate_agent(env, agent=random_agent, num_episodes=100)
reward_agent = evaluate_agent(env, agent=agent, num_episodes=100)

print("Mean Reward, agent:", reward_agent, "random,", reward_random)
# Out:
# torch.Size([3])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# torch.Size([3, 1])
# ...
# tensor([-0.5441])
# torch.Size([3])
# Normal(loc: tensor([0.2383], grad_fn=<MulBackward0>), scale: tensor([0.4121], grad_fn=<SigmoidBackward0>))
# tensor([0.1880])
# torch.Size([3])
# Normal(loc: tensor([0.2349], grad_fn=<MulBackward0>), scale: tensor([0.4097], grad_fn=<SigmoidBackward0>))
# tensor([0.3805])
# torch.Size([3])
# Normal(loc: tensor([0.2279], grad_fn=<MulBackward0>), scale: tensor([0.4063], grad_fn=<SigmoidBackward0>))
# tensor([-0.3513])
# torch.Size([3])
# Normal(loc: tensor([0.2286], grad_fn=<MulBackward0>), scale: tensor([0.4071], grad_fn=<SigmoidBackward0>))
# tensor([0.4583])
# torch.Size([3])
# Normal(loc: tensor([0.2221], grad_fn=<MulBackward0>), scale: tensor([0.4033], grad_fn=<SigmoidBackward0>))
# tensor([-0.6373])
# torch.Size([3])
# Normal(loc: tensor([0.2241], grad_fn=<MulBackward0>), scale: tensor([0.4061], grad_fn=<SigmoidBackward0>))
# tensor([0.3540])
# torch.Size([3])
# Normal(loc: tensor([0.2206], grad_fn=<MulBackward0>), scale: tensor([0.4032], grad_fn=<SigmoidBackward0>))
# tensor([0.2501])
# torch.Size([3])
# Normal(loc: tensor([0.2211], grad_fn=<MulBackward0>), scale: tensor([0.4010], grad_fn=<SigmoidBackward0>))
# tensor([1.0801])
# torch.Size([3])
# Normal(loc: tensor([0.2223], grad_fn=<MulBackward0>), scale: tensor([0.3929], grad_fn=<SigmoidBackward0>))
# tensor([0.5354])
# torch.Size([3])
# Normal(loc: tensor([0.2226], grad_fn=<MulBackward0>), scale: tensor([0.3895], grad_fn=<SigmoidBackward0>))
# tensor([0.1818])
# torch.Size([3])
# Normal(loc: tensor([0.2208], grad_fn=<MulBackward0>), scale: tensor([0.3893], grad_fn=<SigmoidBackward0>))
# tensor([0.4037])
# torch.Size([3])
# Normal(loc: tensor([0.2194], grad_fn=<MulBackward0>), scale: tensor([0.3884], grad_fn=<SigmoidBackward0>))
# tensor([0.3112])
# torch.Size([3])
# Normal(loc: tensor([0.2171], grad_fn=<MulBackward0>), scale: tensor([0.3889], grad_fn=<SigmoidBackward0>))
# tensor([0.5772])
# torch.Size([3])
# Normal(loc: tensor([0.2155], grad_fn=<MulBackward0>), scale: tensor([0.3885], grad_fn=<SigmoidBackward0>))
# tensor([0.3912])
# torch.Size([3])
# Normal(loc: tensor([0.2126], grad_fn=<MulBackward0>), scale: tensor([0.3901], grad_fn=<SigmoidBackward0>))
# tensor([-0.2419])
# torch.Size([3])
# Normal(loc: tensor([0.2069], grad_fn=<MulBackward0>), scale: tensor([0.3969], grad_fn=<SigmoidBackward0>))
# tensor([0.1645])
# torch.Size([3])
# Normal(loc: tensor([0.2027], grad_fn=<MulBackward0>), scale: tensor([0.4013], grad_fn=<SigmoidBackward0>))
# tensor([0.8267])
# torch.Size([3])
# Normal(loc: tensor([0.2016], grad_fn=<MulBackward0>), scale: tensor([0.4014], grad_fn=<SigmoidBackward0>))
# tensor([0.2769])
# torch.Size([3])
# Normal(loc: tensor([0.1941], grad_fn=<MulBackward0>), scale: tensor([0.4052], grad_fn=<SigmoidBackward0>))
# tensor([-0.3569])
# torch.Size([3])
# Normal(loc: tensor([0.1992], grad_fn=<MulBackward0>), scale: tensor([0.4132], grad_fn=<SigmoidBackward0>))
# tensor([1.1890])
# torch.Size([3])
# Normal(loc: tensor([0.1974], grad_fn=<MulBackward0>), scale: tensor([0.4111], grad_fn=<SigmoidBackward0>))
# tensor([0.2891])
# torch.Size([3])
# Normal(loc: tensor([0.2027], grad_fn=<MulBackward0>), scale: tensor([0.4153], grad_fn=<SigmoidBackward0>))
# tensor([-0.0753])
# torch.Size([3])
# Normal(loc: tensor([0.2148], grad_fn=<MulBackward0>), scale: tensor([0.4223], grad_fn=<SigmoidBackward0>))
# tensor([-0.0568])
# torch.Size([3])
# Normal(loc: tensor([0.2227], grad_fn=<MulBackward0>), scale: tensor([0.4281], grad_fn=<SigmoidBackward0>))
# tensor([0.0212])
# torch.Size([3])
# Normal(loc: tensor([0.2396], grad_fn=<MulBackward0>), scale: tensor([0.4312], grad_fn=<SigmoidBackward0>))
# tensor([0.1898])
# torch.Size([3])
# Normal(loc: tensor([0.2512], grad_fn=<MulBackward0>), scale: tensor([0.4328], grad_fn=<SigmoidBackward0>))
# tensor([0.3776])
# torch.Size([3])
# Normal(loc: tensor([0.2547], grad_fn=<MulBackward0>), scale: tensor([0.4326], grad_fn=<SigmoidBackward0>))
# tensor([-0.1638])
# torch.Size([3])
# Normal(loc: tensor([0.2626], grad_fn=<MulBackward0>), scale: tensor([0.4339], grad_fn=<SigmoidBackward0>))
# tensor([0.4361])
# torch.Size([3])
# Normal(loc: tensor([0.2601], grad_fn=<MulBackward0>), scale: tensor([0.4321], grad_fn=<SigmoidBackward0>))
# tensor([0.5263])
# torch.Size([3])
# Normal(loc: tensor([0.2540], grad_fn=<MulBackward0>), scale: tensor([0.4293], grad_fn=<SigmoidBackward0>))
# tensor([-0.0349])
# torch.Size([3])
# Normal(loc: tensor([0.2539], grad_fn=<MulBackward0>), scale: tensor([0.4284], grad_fn=<SigmoidBackward0>))
# tensor([0.5383])
# torch.Size([3])
# Normal(loc: tensor([0.2532], grad_fn=<MulBackward0>), scale: tensor([0.4239], grad_fn=<SigmoidBackward0>))
# tensor([-0.2636])
# torch.Size([3])
# Normal(loc: tensor([0.2546], grad_fn=<MulBackward0>), scale: tensor([0.4231], grad_fn=<SigmoidBackward0>))
# tensor([0.1767])
# torch.Size([3])
# Normal(loc: tensor([0.2560], grad_fn=<MulBackward0>), scale: tensor([0.4194], grad_fn=<SigmoidBackward0>))
# tensor([1.0221])
# torch.Size([3])
# Normal(loc: tensor([0.2468], grad_fn=<MulBackward0>), scale: tensor([0.4105], grad_fn=<SigmoidBackward0>))
# tensor([-0.1665])
# torch.Size([3])
# Normal(loc: tensor([0.2440], grad_fn=<MulBackward0>), scale: tensor([0.4084], grad_fn=<SigmoidBackward0>))
# tensor([0.7707])
# torch.Size([3])
# Normal(loc: tensor([0.2304], grad_fn=<MulBackward0>), scale: tensor([0.4008], grad_fn=<SigmoidBackward0>))
# tensor([0.5927])
# torch.Size([3])
# Normal(loc: tensor([0.2311], grad_fn=<MulBackward0>), scale: tensor([0.3936], grad_fn=<SigmoidBackward0>))
# tensor([0.0869])
# torch.Size([3])
# Normal(loc: tensor([0.2297], grad_fn=<MulBackward0>), scale: tensor([0.3900], grad_fn=<SigmoidBackward0>))
# tensor([1.0965])
# torch.Size([3])
# Normal(loc: tensor([0.2314], grad_fn=<MulBackward0>), scale: tensor([0.3808], grad_fn=<SigmoidBackward0>))
# tensor([0.3489])
# torch.Size([3])
# Normal(loc: tensor([0.2300], grad_fn=<MulBackward0>), scale: tensor([0.3777], grad_fn=<SigmoidBackward0>))
# tensor([0.3529])
# torch.Size([3])
# Normal(loc: tensor([0.2280], grad_fn=<MulBackward0>), scale: tensor([0.3759], grad_fn=<SigmoidBackward0>))
# tensor([0.4063])
# torch.Size([3])
# Normal(loc: tensor([0.2256], grad_fn=<MulBackward0>), scale: tensor([0.3749], grad_fn=<SigmoidBackward0>))
# tensor([0.4446])
# torch.Size([3])
# Normal(loc: tensor([0.2228], grad_fn=<MulBackward0>), scale: tensor([0.3750], grad_fn=<SigmoidBackward0>))
# tensor([0.0439])
# torch.Size([3])
# Normal(loc: tensor([0.2190], grad_fn=<MulBackward0>), scale: tensor([0.3789], grad_fn=<SigmoidBackward0>))
# tensor([-0.0517])
# torch.Size([3])
# Normal(loc: tensor([0.2119], grad_fn=<MulBackward0>), scale: tensor([0.3849], grad_fn=<SigmoidBackward0>))
# tensor([-0.1236])
# torch.Size([3])
# Normal(loc: tensor([0.2054], grad_fn=<MulBackward0>), scale: tensor([0.3924], grad_fn=<SigmoidBackward0>))
# tensor([0.4264])
# torch.Size([3])
# Normal(loc: tensor([0.2013], grad_fn=<MulBackward0>), scale: tensor([0.3969], grad_fn=<SigmoidBackward0>))
# tensor([0.2753])
# torch.Size([3])
# Normal(loc: tensor([0.1947], grad_fn=<MulBackward0>), scale: tensor([0.4026], grad_fn=<SigmoidBackward0>))
# tensor([0.7077])
# torch.Size([3])
# Normal(loc: tensor([0.1890], grad_fn=<MulBackward0>), scale: tensor([0.4054], grad_fn=<SigmoidBackward0>))
# tensor([0.1045])
# torch.Size([3])
# Normal(loc: tensor([0.1899], grad_fn=<MulBackward0>), scale: tensor([0.4123], grad_fn=<SigmoidBackward0>))
# tensor([-0.4777])
# torch.Size([3])
# Normal(loc: tensor([0.2072], grad_fn=<MulBackward0>), scale: tensor([0.4245], grad_fn=<SigmoidBackward0>))
# tensor([-0.0661])
# torch.Size([3])
# Normal(loc: tensor([0.2268], grad_fn=<MulBackward0>), scale: tensor([0.4319], grad_fn=<SigmoidBackward0>))
# tensor([-0.2237])
# torch.Size([3])
# Normal(loc: tensor([0.2531], grad_fn=<MulBackward0>), scale: tensor([0.4380], grad_fn=<SigmoidBackward0>))
# tensor([0.2159])
# torch.Size([3])
# Normal(loc: tensor([0.2594], grad_fn=<MulBackward0>), scale: tensor([0.4399], grad_fn=<SigmoidBackward0>))
# tensor([0.6894])
# torch.Size([3])
# Normal(loc: tensor([0.2634], grad_fn=<MulBackward0>), scale: tensor([0.4388], grad_fn=<SigmoidBackward0>))
# tensor([0.4824])
# torch.Size([3])
# Normal(loc: tensor([0.2666], grad_fn=<MulBackward0>), scale: tensor([0.4379], grad_fn=<SigmoidBackward0>))
# tensor([0.4759])
# torch.Size([3])
# Normal(loc: tensor([0.2678], grad_fn=<MulBackward0>), scale: tensor([0.4361], grad_fn=<SigmoidBackward0>))
# tensor([-0.3353])
# torch.Size([3])
# Normal(loc: tensor([0.2717], grad_fn=<MulBackward0>), scale: tensor([0.4371], grad_fn=<SigmoidBackward0>))
# tensor([0.1605])
# torch.Size([3])
# Normal(loc: tensor([0.2745], grad_fn=<MulBackward0>), scale: tensor([0.4352], grad_fn=<SigmoidBackward0>))
# tensor([-0.3521])
# torch.Size([3])
# Normal(loc: tensor([0.2776], grad_fn=<MulBackward0>), scale: tensor([0.4348], grad_fn=<SigmoidBackward0>))
# tensor([-0.3584])
# torch.Size([3])
# Normal(loc: tensor([0.2787], grad_fn=<MulBackward0>), scale: tensor([0.4338], grad_fn=<SigmoidBackward0>))
# tensor([-0.3902])
# torch.Size([3])
# Normal(loc: tensor([0.2782], grad_fn=<MulBackward0>), scale: tensor([0.4322], grad_fn=<SigmoidBackward0>))
# tensor([0.0077])
# torch.Size([3])
# Normal(loc: tensor([0.2695], grad_fn=<MulBackward0>), scale: tensor([0.4283], grad_fn=<SigmoidBackward0>))
# tensor([0.6725])
# torch.Size([3])
# Normal(loc: tensor([0.2633], grad_fn=<MulBackward0>), scale: tensor([0.4200], grad_fn=<SigmoidBackward0>))
# tensor([0.7205])
# torch.Size([3])
# Normal(loc: tensor([0.2644], grad_fn=<MulBackward0>), scale: tensor([0.4121], grad_fn=<SigmoidBackward0>))
# tensor([0.5813])
# torch.Size([3])
# Normal(loc: tensor([0.2496], grad_fn=<MulBackward0>), scale: tensor([0.4020], grad_fn=<SigmoidBackward0>))
# tensor([-0.7795])
# torch.Size([3])
# Normal(loc: tensor([0.2456], grad_fn=<MulBackward0>), scale: tensor([0.4005], grad_fn=<SigmoidBackward0>))
# tensor([-0.1481])
# torch.Size([3])
# Normal(loc: tensor([0.2426], grad_fn=<MulBackward0>), scale: tensor([0.3955], grad_fn=<SigmoidBackward0>))
# tensor([0.4054])
# torch.Size([3])
# Normal(loc: tensor([0.2388], grad_fn=<MulBackward0>), scale: tensor([0.3867], grad_fn=<SigmoidBackward0>))
# tensor([0.3918])
# torch.Size([3])
# Normal(loc: tensor([0.2368], grad_fn=<MulBackward0>), scale: tensor([0.3787], grad_fn=<SigmoidBackward0>))
# tensor([0.4772])
# torch.Size([3])
# Normal(loc: tensor([0.2382], grad_fn=<MulBackward0>), scale: tensor([0.3718], grad_fn=<SigmoidBackward0>))
# tensor([0.1511])
# torch.Size([3])
# Normal(loc: tensor([0.2417], grad_fn=<MulBackward0>), scale: tensor([0.3685], grad_fn=<SigmoidBackward0>))
# tensor([-0.1482])
# torch.Size([3])
# Normal(loc: tensor([0.2378], grad_fn=<MulBackward0>), scale: tensor([0.3686], grad_fn=<SigmoidBackward0>))
# tensor([0.3645])
# torch.Size([3])
# Normal(loc: tensor([0.2373], grad_fn=<MulBackward0>), scale: tensor([0.3670], grad_fn=<SigmoidBackward0>))
# tensor([-0.4113])
# torch.Size([3])
# Normal(loc: tensor([0.2247], grad_fn=<MulBackward0>), scale: tensor([0.3719], grad_fn=<SigmoidBackward0>))
# tensor([0.6432])
# torch.Size([3])
# Normal(loc: tensor([0.2211], grad_fn=<MulBackward0>), scale: tensor([0.3715], grad_fn=<SigmoidBackward0>))
# tensor([0.2753])
# torch.Size([3])
# Normal(loc: tensor([0.2172], grad_fn=<MulBackward0>), scale: tensor([0.3748], grad_fn=<SigmoidBackward0>))
# tensor([-0.0697])
# torch.Size([3])
# Normal(loc: tensor([0.2109], grad_fn=<MulBackward0>), scale: tensor([0.3818], grad_fn=<SigmoidBackward0>))
# tensor([0.0862])
# torch.Size([3])
# Normal(loc: tensor([0.2042], grad_fn=<MulBackward0>), scale: tensor([0.3891], grad_fn=<SigmoidBackward0>))
# tensor([-0.0839])
# torch.Size([3])
# Normal(loc: tensor([0.1970], grad_fn=<MulBackward0>), scale: tensor([0.3984], grad_fn=<SigmoidBackward0>))
# tensor([-0.0242])
# torch.Size([3])
# Normal(loc: tensor([0.1838], grad_fn=<MulBackward0>), scale: tensor([0.4069], grad_fn=<SigmoidBackward0>))
# tensor([-0.2742])
# torch.Size([3])
# Normal(loc: tensor([0.1919], grad_fn=<MulBackward0>), scale: tensor([0.4179], grad_fn=<SigmoidBackward0>))
# tensor([0.0345])
# torch.Size([3])
# Normal(loc: tensor([0.2067], grad_fn=<MulBackward0>), scale: tensor([0.4272], grad_fn=<SigmoidBackward0>))
# tensor([-0.2094])
# torch.Size([3])
# Normal(loc: tensor([0.2367], grad_fn=<MulBackward0>), scale: tensor([0.4356], grad_fn=<SigmoidBackward0>))
# tensor([0.4077])
# torch.Size([3])
# Normal(loc: tensor([0.2522], grad_fn=<MulBackward0>), scale: tensor([0.4386], grad_fn=<SigmoidBackward0>))
# tensor([0.7344])
# torch.Size([3])
# Normal(loc: tensor([0.2567], grad_fn=<MulBackward0>), scale: tensor([0.4385], grad_fn=<SigmoidBackward0>))
# tensor([0.3354])
# torch.Size([3])
# Normal(loc: tensor([0.2614], grad_fn=<MulBackward0>), scale: tensor([0.4394], grad_fn=<SigmoidBackward0>))
# tensor([0.5822])
# torch.Size([3])
# Normal(loc: tensor([0.2652], grad_fn=<MulBackward0>), scale: tensor([0.4384], grad_fn=<SigmoidBackward0>))
# tensor([0.0520])
# torch.Size([3])
# Normal(loc: tensor([0.2662], grad_fn=<MulBackward0>), scale: tensor([0.4387], grad_fn=<SigmoidBackward0>))
# tensor([-0.1077])
# torch.Size([3])
# Normal(loc: tensor([0.2672], grad_fn=<MulBackward0>), scale: tensor([0.4389], grad_fn=<SigmoidBackward0>))
# tensor([0.0777])
# torch.Size([3])
# Normal(loc: tensor([0.2720], grad_fn=<MulBackward0>), scale: tensor([0.4375], grad_fn=<SigmoidBackward0>))
# tensor([-0.1181])
# torch.Size([3])
# Normal(loc: tensor([0.2762], grad_fn=<MulBackward0>), scale: tensor([0.4362], grad_fn=<SigmoidBackward0>))
# tensor([0.9416])
# torch.Size([3])
# Normal(loc: tensor([0.2669], grad_fn=<MulBackward0>), scale: tensor([0.4300], grad_fn=<SigmoidBackward0>))
# tensor([0.3948])
# torch.Size([3])
# Normal(loc: tensor([0.2575], grad_fn=<MulBackward0>), scale: tensor([0.4252], grad_fn=<SigmoidBackward0>))
# tensor([0.4932])
# torch.Size([3])
# Normal(loc: tensor([0.2604], grad_fn=<MulBackward0>), scale: tensor([0.4184], grad_fn=<SigmoidBackward0>))
# tensor([0.9795])
# torch.Size([3])
# Normal(loc: tensor([0.2544], grad_fn=<MulBackward0>), scale: tensor([0.4092], grad_fn=<SigmoidBackward0>))
# tensor([0.6634])
# torch.Size([3])
# Normal(loc: tensor([0.2386], grad_fn=<MulBackward0>), scale: tensor([0.4004], grad_fn=<SigmoidBackward0>))
# tensor([0.4155])
# torch.Size([3])
# Normal(loc: tensor([0.2368], grad_fn=<MulBackward0>), scale: tensor([0.3931], grad_fn=<SigmoidBackward0>))
# tensor([-0.1554])
# torch.Size([3])
# Normal(loc: tensor([0.2353], grad_fn=<MulBackward0>), scale: tensor([0.3893], grad_fn=<SigmoidBackward0>))
# tensor([0.7248])
# torch.Size([3])
# Normal(loc: tensor([0.2341], grad_fn=<MulBackward0>), scale: tensor([0.3807], grad_fn=<SigmoidBackward0>))
# tensor([0.2070])
# torch.Size([3])
# Normal(loc: tensor([0.2329], grad_fn=<MulBackward0>), scale: tensor([0.3770], grad_fn=<SigmoidBackward0>))
# tensor([0.6559])
# torch.Size([3])
# Normal(loc: tensor([0.2325], grad_fn=<MulBackward0>), scale: tensor([0.3716], grad_fn=<SigmoidBackward0>))
# tensor([0.4100])
# torch.Size([3])
# Normal(loc: tensor([0.2342], grad_fn=<MulBackward0>), scale: tensor([0.3692], grad_fn=<SigmoidBackward0>))
# tensor([0.0161])
# torch.Size([3])
# Normal(loc: tensor([0.2272], grad_fn=<MulBackward0>), scale: tensor([0.3708], grad_fn=<SigmoidBackward0>))
# tensor([-0.4540])
# torch.Size([3])
# Normal(loc: tensor([0.2217], grad_fn=<MulBackward0>), scale: tensor([0.3769], grad_fn=<SigmoidBackward0>))
# tensor([0.1804])
# torch.Size([3])
# Normal(loc: tensor([0.2176], grad_fn=<MulBackward0>), scale: tensor([0.3802], grad_fn=<SigmoidBackward0>))
# tensor([0.1321])
# torch.Size([3])
# Normal(loc: tensor([0.2115], grad_fn=<MulBackward0>), scale: tensor([0.3851], grad_fn=<SigmoidBackward0>))
# tensor([0.8163])
# torch.Size([3])
# Normal(loc: tensor([0.2085], grad_fn=<MulBackward0>), scale: tensor([0.3863], grad_fn=<SigmoidBackward0>))
# tensor([-0.0711])
# torch.Size([3])
# Normal(loc: tensor([0.2017], grad_fn=<MulBackward0>), scale: tensor([0.3945], grad_fn=<SigmoidBackward0>))
# tensor([0.6379])
# torch.Size([3])
# Normal(loc: tensor([0.1981], grad_fn=<MulBackward0>), scale: tensor([0.3984], grad_fn=<SigmoidBackward0>))
# tensor([0.8109])
# torch.Size([3])
# Normal(loc: tensor([0.1946], grad_fn=<MulBackward0>), scale: tensor([0.4014], grad_fn=<SigmoidBackward0>))
# tensor([0.1241])
# torch.Size([3])
# Normal(loc: tensor([0.1834], grad_fn=<MulBackward0>), scale: tensor([0.4086], grad_fn=<SigmoidBackward0>))
# tensor([-0.2604])
# Mean Reward, agent: -1330.151634156803 random, [-1356.3018]

# %%
for epoch in range(NB_EPOCH):
    rewards, loss, entropy, episodes_length = train_epoch(env, agent=agent, optimizer=optimizer, gamma=GAMMA, num_episode=BATCH_SIZE)

    print("Epoch", epoch, "reward:", torch.FloatTensor(rewards).mean().item())

    writer.add_scalar("mean_reward", torch.FloatTensor(rewards).mean(), epoch)
    writer.add_scalar("mean_length", torch.FloatTensor(episodes_length).mean(), epoch)
    writer.add_scalar("loss", loss, epoch)
    writer.add_scalar("entropy", entropy, epoch)
# Out:
# torch.Size([1, 3])
# Normal(loc: torch.Size([0, 2]), scale: torch.Size([0, 2]))
# tensor([], size=(0, 2))
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/lulu/Worskpace/rl-journey/notebooks/vanilla_policy_gradient_pendulum.ipynb Cell 14 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/Users/lulu/Worskpace/rl-journey/notebooks/vanilla_policy_gradient_pendulum.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> for epoch in range(NB_EPOCH):
# ----> <a href='vscode-notebook-cell:/Users/lulu/Worskpace/rl-journey/notebooks/vanilla_policy_gradient_pendulum.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a>     rewards, loss, entropy, episodes_length = train_epoch(env, agent=agent, optimizer=optimizer, gamma=GAMMA, num_episode=BATCH_SIZE)
#       <a href='vscode-notebook-cell:/Users/lulu/Worskpace/rl-journey/notebooks/vanilla_policy_gradient_pendulum.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a>     print("Epoch", epoch, "reward:", torch.FloatTensor(rewards).mean().item())
#       <a href='vscode-notebook-cell:/Users/lulu/Worskpace/rl-journey/notebooks/vanilla_policy_gradient_pendulum.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a>     writer.add_scalar("mean_reward", torch.FloatTensor(rewards).mean(), epoch)
#
# /Users/lulu/Worskpace/rl-journey/notebooks/vanilla_policy_gradient_pendulum.ipynb Cell 14 in train_epoch(env, agent, optimizer, gamma, num_episode)
#      <a href='vscode-notebook-cell:/Users/lulu/Worskpace/rl-journey/notebooks/vanilla_policy_gradient_pendulum.ipynb#X16sZmlsZQ%3D%3D?line=53'>54</a> print(torch_state.shape)
#      <a href='vscode-notebook-cell:/Users/lulu/Worskpace/rl-journey/notebooks/vanilla_policy_gradient_pendulum.ipynb#X16sZmlsZQ%3D%3D?line=54'>55</a> torch_action = agent.action(torch_state)
# ---> <a href='vscode-notebook-cell:/Users/lulu/Worskpace/rl-journey/notebooks/vanilla_policy_gradient_pendulum.ipynb#X16sZmlsZQ%3D%3D?line=56'>57</a> next_observation, reward, terminated, truncarted, info = env.step(torch_action.numpy())
#      <a href='vscode-notebook-cell:/Users/lulu/Worskpace/rl-journey/notebooks/vanilla_policy_gradient_pendulum.ipynb#X16sZmlsZQ%3D%3D?line=57'>58</a> if type(reward) != "int":
#      <a href='vscode-notebook-cell:/Users/lulu/Worskpace/rl-journey/notebooks/vanilla_policy_gradient_pendulum.ipynb#X16sZmlsZQ%3D%3D?line=58'>59</a>     reward = reward[0]
#
# File ~/Worskpace/rl-journey/.venv/lib/python3.10/site-packages/gym/wrappers/time_limit.py:60, in TimeLimit.step(self, action)
#      48 def step(self, action):
#      49     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      50
#      51     Args:
#    (...)
#      57         "TimeLimit.truncated"=False if the environment terminated
#      58     """
#      59     observation, reward, terminated, truncated, info = step_api_compatibility(
# ---> 60         self.env.step(action),
#      61         True,
#      62     )
#      63     self._elapsed_steps += 1
#      65     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/Worskpace/rl-journey/.venv/lib/python3.10/site-packages/gym/wrappers/order_enforcing.py:37, in OrderEnforcing.step(self, action)
#      35 if not self._has_reset:
#      36     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 37 return self.env.step(action)
#
# File ~/Worskpace/rl-journey/.venv/lib/python3.10/site-packages/gym/wrappers/step_api_compatibility.py:52, in StepAPICompatibility.step(self, action)
#      43 def step(self, action):
#      44     """Steps through the environment, returning 5 or 4 items depending on `new_step_api`.
#      45
#      46     Args:
#    (...)
#      50         (observation, reward, terminated, truncated, info) or (observation, reward, done, info)
#      51     """
# ---> 52     step_returns = self.env.step(action)
#      53     if self.new_step_api:
#      54         return step_to_new_api(step_returns)
#
# File ~/Worskpace/rl-journey/.venv/lib/python3.10/site-packages/gym/wrappers/env_checker.py:39, in PassiveEnvChecker.step(self, action)
#      37     return env_step_passive_checker(self.env, action)
#      38 else:
# ---> 39     return self.env.step(action)
#
# File ~/Worskpace/rl-journey/.venv/lib/python3.10/site-packages/gym/envs/classic_control/pendulum.py:129, in PendulumEnv.step(self, u)
#     126 l = self.l
#     127 dt = self.dt
# --> 129 u = np.clip(u, -self.max_torque, self.max_torque)[0]
#     130 self.last_u = u  # for rendering
#     131 costs = angle_normalize(th) ** 2 + 0.1 * thdot**2 + 0.001 * (u**2)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
reward_random = evaluate_agent(env, agent=random_agent, num_episodes=100)
reward_agent = evaluate_agent(env, agent=agent, num_episodes=100)

print("Mean Reward, agent:", reward_agent, "random,", reward_random)
# Out:
# Mean Reward, agent: -1602.2788122885897 random, [-1380.9838]

# %%
reward = play_episode(env, agent=agent, record_path=RECORD_PATH)

print("Reward:", reward)
# Out:
# /Users/lulu/Worskpace/rl-journey/.venv/lib/python3.10/site-packages/gym/wrappers/monitoring/video_recorder.py:78: DeprecationWarning: WARN: Recording ability for environment Pendulum-v1 initialized with `render_mode=None` is marked as deprecated and will be removed in the future.
#   logger.deprecation(
# /Users/lulu/Worskpace/rl-journey/.venv/lib/python3.10/site-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# /Users/lulu/Worskpace/rl-journey/.venv/lib/python3.10/site-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# Reward: -1593.0687357262032
